# %% [markdown]
# <a href="https://colab.research.google.com/github/risshabhraj/Car_Project/blob/master/Copy_of_Car_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **EDA on car dataset**

# %% [markdown]
# **Importing the dataset and the necessary libraries**

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# importing warnings to ignore or filter any warning occuring in the program.
import warnings
warnings.filterwarnings("ignore")
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# **Loading & reading the Dataset**

# %%
car_data = pd.read_csv("data.csv")
car_data
# Out:
#           Make       Model  Year  ... city mpg  Popularity   MSRP
# 0          BMW  1 Series M  2011  ...       19        3916  46135
# 1          BMW    1 Series  2011  ...       19        3916  40650
# 2          BMW    1 Series  2011  ...       20        3916  36350
# 3          BMW    1 Series  2011  ...       18        3916  29450
# 4          BMW    1 Series  2011  ...       18        3916  34500
# ...        ...         ...   ...  ...      ...         ...    ...
# 11909    Acura         ZDX  2012  ...       16         204  46120
# 11910    Acura         ZDX  2012  ...       16         204  56670
# 11911    Acura         ZDX  2012  ...       16         204  50620
# 11912    Acura         ZDX  2013  ...       16         204  50920
# 11913  Lincoln      Zephyr  2006  ...       17          61  28995
#
# [11914 rows x 16 columns]

# %%
car_data.head()
# Out:
#   Make       Model  Year  ... city mpg  Popularity   MSRP
# 0  BMW  1 Series M  2011  ...       19        3916  46135
# 1  BMW    1 Series  2011  ...       19        3916  40650
# 2  BMW    1 Series  2011  ...       20        3916  36350
# 3  BMW    1 Series  2011  ...       18        3916  29450
# 4  BMW    1 Series  2011  ...       18        3916  34500
#
# [5 rows x 16 columns]

# %%
car_data.tail()
# Out:
#           Make   Model  Year  ... city mpg  Popularity   MSRP
# 11909    Acura     ZDX  2012  ...       16         204  46120
# 11910    Acura     ZDX  2012  ...       16         204  56670
# 11911    Acura     ZDX  2012  ...       16         204  50620
# 11912    Acura     ZDX  2013  ...       16         204  50920
# 11913  Lincoln  Zephyr  2006  ...       17          61  28995
#
# [5 rows x 16 columns]

# %%
car_data.shape
# Out:
# (11914, 16)

# %% [markdown]
# **Checking Datatype**

# %%
car_data.describe()
# Out:
#                Year    Engine HP  ...    Popularity          MSRP
# count  11914.000000  11845.00000  ...  11914.000000  1.191400e+04
# mean    2010.384338    249.38607  ...   1554.911197  4.059474e+04
# std        7.579740    109.19187  ...   1441.855347  6.010910e+04
# min     1990.000000     55.00000  ...      2.000000  2.000000e+03
# 25%     2007.000000    170.00000  ...    549.000000  2.100000e+04
# 50%     2015.000000    227.00000  ...   1385.000000  2.999500e+04
# 75%     2016.000000    300.00000  ...   2009.000000  4.223125e+04
# max     2017.000000   1001.00000  ...   5657.000000  2.065902e+06
#
# [8 rows x 8 columns]

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
car_data['Make']
# Out:
# 0            BMW
# 1            BMW
# 2            BMW
# 3            BMW
# 4            BMW
#           ...
# 11909      Acura
# 11910      Acura
# 11911      Acura
# 11912      Acura
# 11913    Lincoln
# Name: Make, Length: 11914, dtype: object

# %%
car_data['Make'].value_counts()
# Out:
# Chevrolet        1123
# Ford              881
# Volkswagen        809
# Toyota            746
# Dodge             626
# Nissan            558
# GMC               515
# Honda             449
# Mazda             423
# Cadillac          397
# Mercedes-Benz     353
# Suzuki            351
# BMW               334
# Infiniti          330
# Audi              328
# Hyundai           303
# Volvo             281
# Subaru            256
# Acura             252
# Kia               231
# Mitsubishi        213
# Lexus             202
# Buick             196
# Chrysler          187
# Pontiac           186
# Lincoln           164
# Oldsmobile        150
# Land Rover        143
# Porsche           136
# Saab              111
# Aston Martin       93
# Plymouth           82
# Bentley            74
# Ferrari            69
# FIAT               62
# Scion              60
# Maserati           58
# Lamborghini        52
# Rolls-Royce        31
# Lotus              29
# Tesla              18
# ...

# %%
car_data['Model'].value_counts()
# Out:
# Silverado 1500        156
# Tundra                140
# F-150                 126
# Sierra 1500            90
# Beetle Convertible     89
#                      ...
# MKZ Hybrid              1
# Corniche                1
# 650S Spider             1
# Dawn                    1
# GS F                    1
# Name: Model, Length: 915, dtype: int64

# %%
car_data['MSRP'].describe()
# Out:
# count    1.191400e+04
# mean     4.059474e+04
# std      6.010910e+04
# min      2.000000e+03
# 25%      2.100000e+04
# 50%      2.999500e+04
# 75%      4.223125e+04
# max      2.065902e+06
# Name: MSRP, dtype: float64

# %% [markdown]
# **Finding max MSRP and the company name**

# %%
cd = max(car_data['MSRP'])
car_data['Make'][car_data['MSRP'] == cd]
# Out:
# 11362    Bugatti
# Name: Make, dtype: object

# %% [markdown]
# **Finding the max MSRP each company has for its models**

# %%
msrp_data = car_data.groupby('Make')['MSRP'].max().reset_index()
msrp_data
# Out:
#              Make     MSRP
# 0           Acura   156000
# 1      Alfa Romeo    68400
# 2    Aston Martin   320695
# 3            Audi   199900
# 4             BMW   141200
# 5         Bentley   363000
# 6         Bugatti  2065902
# 7           Buick    49625
# 8        Cadillac   104215
# 9       Chevrolet    92395
# 10       Chrysler    49470
# 11          Dodge   120395
# 12           FIAT    31800
# 13        Ferrari   643330
# 14           Ford   149995
# 15            GMC    71665
# 16        Genesis    54550
# 17         HUMMER    43130
# 18          Honda    47070
# 19        Hyundai    68750
# 20       Infiniti    88850
# 21            Kia    61900
# 22    Lamborghini  1500000
# 23     Land Rover   199495
# 24          Lexus   375000
# 25        Lincoln    76650
# 26          Lotus    93225
# 27       Maserati   182009
# 28        Maybach  1382750
# 29          Mazda    44015
# 30        McLaren   280225
# 31  Mercedes-Benz   495000
# 32     Mitsubishi    38995
# ...

# %% [markdown]
# **Dropping Irrelevant columns**

# %%
car_data = car_data.drop(['Market Category', 'Engine Fuel Type'], axis=1)
car_data.head()
# Out:
#   Make       Model  Year  Engine HP  ...  highway MPG city mpg Popularity   MSRP
# 0  BMW  1 Series M  2011      335.0  ...           26       19       3916  46135
# 1  BMW    1 Series  2011      300.0  ...           28       19       3916  40650
# 2  BMW    1 Series  2011      300.0  ...           28       20       3916  36350
# 3  BMW    1 Series  2011      230.0  ...           28       18       3916  29450
# 4  BMW    1 Series  2011      230.0  ...           28       18       3916  34500
#
# [5 rows x 14 columns]

# %% [markdown]
# **Renaming the Columns**

# %%
car_data = car_data.rename(columns = {"Engine HP": "HP", "Engine Cylinders": "Cylinders", "Transmission Type": "Transmission", "Driven_Wheels": "Drive Mode","highway MPG": "MPG-H", "city mpg": "MPG-C", "MSRP": "Price"})
car_data
# Out:
#           Make       Model  Year     HP  ...  MPG-H MPG-C Popularity  Price
# 0          BMW  1 Series M  2011  335.0  ...     26    19       3916  46135
# 1          BMW    1 Series  2011  300.0  ...     28    19       3916  40650
# 2          BMW    1 Series  2011  300.0  ...     28    20       3916  36350
# 3          BMW    1 Series  2011  230.0  ...     28    18       3916  29450
# 4          BMW    1 Series  2011  230.0  ...     28    18       3916  34500
# ...        ...         ...   ...    ...  ...    ...   ...        ...    ...
# 11909    Acura         ZDX  2012  300.0  ...     23    16        204  46120
# 11910    Acura         ZDX  2012  300.0  ...     23    16        204  56670
# 11911    Acura         ZDX  2012  300.0  ...     23    16        204  50620
# 11912    Acura         ZDX  2013  300.0  ...     23    16        204  50920
# 11913  Lincoln      Zephyr  2006  221.0  ...     26    17         61  28995
#
# [11914 rows x 14 columns]

# %% [markdown]
#  **Checking for any duplicates in the data, checking for null values and missing data and removing them.**

# %%
car_data.isnull()
# Out:
#         Make  Model   Year     HP  ...  MPG-H  MPG-C  Popularity  Price
# 0      False  False  False  False  ...  False  False       False  False
# 1      False  False  False  False  ...  False  False       False  False
# 2      False  False  False  False  ...  False  False       False  False
# 3      False  False  False  False  ...  False  False       False  False
# 4      False  False  False  False  ...  False  False       False  False
# ...      ...    ...    ...    ...  ...    ...    ...         ...    ...
# 11909  False  False  False  False  ...  False  False       False  False
# 11910  False  False  False  False  ...  False  False       False  False
# 11911  False  False  False  False  ...  False  False       False  False
# 11912  False  False  False  False  ...  False  False       False  False
# 11913  False  False  False  False  ...  False  False       False  False
#
# [11914 rows x 14 columns]

# %%
car_data.isnull().sum()
# Out:
# Make                0
# Model               0
# Year                0
# HP                 69
# Cylinders          30
# Transmission        0
# Drive Mode          0
# Number of Doors     6
# Vehicle Size        0
# Vehicle Style       0
# MPG-H               0
# MPG-C               0
# Popularity          0
# Price               0
# dtype: int64

# %%
car_data['HP'].fillna(car_data['HP'].median(), inplace = True)

# %%
car_data['Cylinders'].fillna(car_data['Cylinders'].median(), inplace = True)

# %%
car_data['Number of Doors'].fillna(car_data['Number of Doors'].median(), inplace = True)

# %%
car_data.isnull().sum()
# Out:
# Make               0
# Model              0
# Year               0
# HP                 0
# Cylinders          0
# Transmission       0
# Drive Mode         0
# Number of Doors    0
# Vehicle Size       0
# Vehicle Style      0
# MPG-H              0
# MPG-C              0
# Popularity         0
# Price              0
# dtype: int64

# %% [markdown]
# **Plotting Price from the data set by using seaborn**

# %%
sns.kdeplot(data= car_data['Price'], label = "Price" ,shade = True)

# %%
car_data['Price'].hist(bins=8)

# %%
car_data['Make'].value_counts().plot(kind = 'bar' ,figsize = [15,5])

# %%
car_data['Model'].value_counts().plot(kind = 'bar' ,figsize = [25,5])

# %%
msrp_data1 = msrp_data.set_index('Make')

# %%
msrp_data1.plot(kind = 'pie' , y = 'MSRP', figsize = [25,25])

# %%
sns.pairplot(car_data)
