# %% [markdown]
# <a href="https://colab.research.google.com/github/risshabhraj/Car_Project/blob/master/Car_EDA_ML_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **EDA on car dataset**
#
# ---

# %% [markdown]
# > **1->  Importing the dataset and the necessary libraries**
#
# ---

# %% [markdown]
# > Numpy is used here to perform statistical and algebraic operations.
#
# > Pandas is used here to read CSV file and for data processing.
#
# > Seaborn is used here for data visualization, it provides high level   interface for drawing informative statistical graphics.
#
# > Matplotlib is used here for plotting data with labels.
#
# > Importing warnings to ignore or filter any warning occuring in the program.

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# **1.1-> Data Loading**

# %%
car_data = pd.read_csv("data.csv")
car_data
# Out:
#           Make       Model  Year  ... city mpg  Popularity   MSRP
# 0          BMW  1 Series M  2011  ...       19        3916  46135
# 1          BMW    1 Series  2011  ...       19        3916  40650
# 2          BMW    1 Series  2011  ...       20        3916  36350
# 3          BMW    1 Series  2011  ...       18        3916  29450
# 4          BMW    1 Series  2011  ...       18        3916  34500
# ...        ...         ...   ...  ...      ...         ...    ...
# 11909    Acura         ZDX  2012  ...       16         204  46120
# 11910    Acura         ZDX  2012  ...       16         204  56670
# 11911    Acura         ZDX  2012  ...       16         204  50620
# 11912    Acura         ZDX  2013  ...       16         204  50920
# 11913  Lincoln      Zephyr  2006  ...       17          61  28995
#
# [11914 rows x 16 columns]

# %% [markdown]
# **1.2-> Statistical Summary & Checking Datatype**

# %% [markdown]
# -> Statistical Summary has been performed here to get summarized and organized information of data.
#
# -> Statistical summary include **mean, median, mode, minimum value, maximum value, range, standard deviation** etc.
#
# -> Checking the datatype is important here because data could be stored in integer or string which may cause errors while doing the **data  visualization**

# %% [markdown]
# * **head()** function gives us the first n rows, n could be defined by the user or by default it gives us first 5 rows.

# %%
car_data.head()
# Out:
#   Make       Model  Year  ... city mpg  Popularity   MSRP
# 0  BMW  1 Series M  2011  ...       19        3916  46135
# 1  BMW    1 Series  2011  ...       19        3916  40650
# 2  BMW    1 Series  2011  ...       20        3916  36350
# 3  BMW    1 Series  2011  ...       18        3916  29450
# 4  BMW    1 Series  2011  ...       18        3916  34500
#
# [5 rows x 16 columns]

# %% [markdown]
# * **tail()** function gives us the last n rows, n could be defined by the user or by default it gives us last 5 rows.

# %%
car_data.tail()
# Out:
#           Make   Model  Year  ... city mpg  Popularity   MSRP
# 11909    Acura     ZDX  2012  ...       16         204  46120
# 11910    Acura     ZDX  2012  ...       16         204  56670
# 11911    Acura     ZDX  2012  ...       16         204  50620
# 11912    Acura     ZDX  2013  ...       16         204  50920
# 11913  Lincoln  Zephyr  2006  ...       17          61  28995
#
# [5 rows x 16 columns]

# %% [markdown]
# * **shape** funtion returns the shape of an array, the numbers given out as an ouput denotes the lenght of the corresponding array dimension.

# %%
car_data.shape
# Out:
# (11914, 16)

# %% [markdown]
# * **describe** funtion computes a summary statitics pertaining to the dataframe columns. It gives us mean, std and IQR values.

# %%
car_data.describe()
# Out:
#                Year    Engine HP  ...    Popularity          MSRP
# count  11914.000000  11845.00000  ...  11914.000000  1.191400e+04
# mean    2010.384338    249.38607  ...   1554.911197  4.059474e+04
# std        7.579740    109.19187  ...   1441.855347  6.010910e+04
# min     1990.000000     55.00000  ...      2.000000  2.000000e+03
# 25%     2007.000000    170.00000  ...    549.000000  2.100000e+04
# 50%     2015.000000    227.00000  ...   1385.000000  2.999500e+04
# 75%     2016.000000    300.00000  ...   2009.000000  4.223125e+04
# max     2017.000000   1001.00000  ...   5657.000000  2.065902e+06
#
# [8 rows x 8 columns]

# %% [markdown]
# * **info** function gives us a concise summary of a dataframe including the index, dtype, columns, non-null values, it is used here to find if the dataframe contains any null value.

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
car_data['Make']
# Out:
# 0            BMW
# 1            BMW
# 2            BMW
# 3            BMW
# 4            BMW
#           ...
# 11909      Acura
# 11910      Acura
# 11911      Acura
# 11912      Acura
# 11913    Lincoln
# Name: Make, Length: 11914, dtype: object

# %% [markdown]
# * **value_counts** funtion returns a series containing **counts of unique values**. The resulting object will be in **descending** order so that the first element is the most frequently-occurring element. **Excludes NA** values by default.

# %%
car_data['Make'].value_counts()
# Out:
# Chevrolet        1123
# Ford              881
# Volkswagen        809
# Toyota            746
# Dodge             626
# Nissan            558
# GMC               515
# Honda             449
# Mazda             423
# Cadillac          397
# Mercedes-Benz     353
# Suzuki            351
# BMW               334
# Infiniti          330
# Audi              328
# Hyundai           303
# Volvo             281
# Subaru            256
# Acura             252
# Kia               231
# Mitsubishi        213
# Lexus             202
# Buick             196
# Chrysler          187
# Pontiac           186
# Lincoln           164
# Oldsmobile        150
# Land Rover        143
# Porsche           136
# Saab              111
# Aston Martin       93
# Plymouth           82
# Bentley            74
# Ferrari            69
# FIAT               62
# Scion              60
# Maserati           58
# Lamborghini        52
# Rolls-Royce        31
# Lotus              29
# Tesla              18
# ...

# %% [markdown]
# From the output we can infer that **Chevrolet** is the most frequently occuring company & **Genesis, Bugatti & Spyker** the least occuring company in the dataframe.

# %%
car_data['Model'].value_counts()
# Out:
# Silverado 1500                      156
# Tundra                              140
# F-150                               126
# Sierra 1500                          90
# Beetle Convertible                   89
#                                    ...
# Continental GT Speed Convertible      1
# California T                          1
# Pulsar                                1
# G3                                    1
# XC                                    1
# Name: Model, Length: 915, dtype: int64

# %% [markdown]
# From the output we can infer that **Silverado 1500** is the most frequently occuring Model & **Azure T, Precis, ML55 AMG, California T & Sierra C3** the least occuring company in the dataframe.

# %% [markdown]
# > **2-> Dropping Irrelevant columns**
#
# ---

# %% [markdown]
# * **Dropping Irrelevant Columns** is an important step to make the final output to be more accurate and precise. By dropping the irrelevant columns we are removing the columns which we will not use further to decide or predict the result and we do this so that we give more focus to the columns which can be usefull and will help in further calculations or viualizations.

# %% [markdown]
# * Here we are removing **Market category and Engine Fuel** type because removing them will not effect my final result and are not usefull in data visualization.

# %%
car_data = car_data.drop(['Market Category', 'Engine Fuel Type'], axis=1)
car_data.head()
# Out:
#   Make       Model  Year  Engine HP  ...  highway MPG city mpg Popularity   MSRP
# 0  BMW  1 Series M  2011      335.0  ...           26       19       3916  46135
# 1  BMW    1 Series  2011      300.0  ...           28       19       3916  40650
# 2  BMW    1 Series  2011      300.0  ...           28       20       3916  36350
# 3  BMW    1 Series  2011      230.0  ...           28       18       3916  29450
# 4  BMW    1 Series  2011      230.0  ...           28       18       3916  34500
#
# [5 rows x 14 columns]

# %% [markdown]
# > **3-> Renaming the Columns**
#
# ---

# %% [markdown]
# Renaming the columns are done because sometimes columns names could be unclear or confusing, so by renaming the column we can improve understanding of the column and the data under that column.

# %% [markdown]
# * To rename a column in python **rename** function is used.

# %%
car_data = car_data.rename(columns = {"Engine HP": "HP", "Engine Cylinders": "Cylinders", "Transmission Type": "Transmission", "Driven_Wheels": "Drive Mode","highway MPG": "MPG-H", "city mpg": "MPG-C", "MSRP": "Price"})
car_data
# Out:
#           Make       Model  Year     HP  ...  MPG-H MPG-C Popularity  Price
# 0          BMW  1 Series M  2011  335.0  ...     26    19       3916  46135
# 1          BMW    1 Series  2011  300.0  ...     28    19       3916  40650
# 2          BMW    1 Series  2011  300.0  ...     28    20       3916  36350
# 3          BMW    1 Series  2011  230.0  ...     28    18       3916  29450
# 4          BMW    1 Series  2011  230.0  ...     28    18       3916  34500
# ...        ...         ...   ...    ...  ...    ...   ...        ...    ...
# 11909    Acura         ZDX  2012  300.0  ...     23    16        204  46120
# 11910    Acura         ZDX  2012  300.0  ...     23    16        204  56670
# 11911    Acura         ZDX  2012  300.0  ...     23    16        204  50620
# 11912    Acura         ZDX  2013  300.0  ...     23    16        204  50920
# 11913  Lincoln      Zephyr  2006  221.0  ...     26    17         61  28995
#
# [11914 rows x 14 columns]

# %% [markdown]
# > **4-> Checking for any duplicates in the data, checking for null values and missing data.**
#
# ---

# %% [markdown]
# Checking for duplicate data and null values are one of the most important steps as this could bring a huge difference in data viualization and final results.

# %% [markdown]
# * Large datasets contains duplicate data and so by using **duplicated** function we find the duplicate data.

# %%
duplicate_rows_car_data =  car_data[car_data.duplicated()]
duplicate_rows_car_data.shape
# Out:
# (791, 14)

# %% [markdown]
# We can observe from the above output that there are **791 rows** having duplicate data.

# %% [markdown]
# * By using **drop_duplicates** function we drop the duplicate data that we found using **duplicated** function.

# %%
car_data = car_data.drop_duplicates()
car_data.head(5)
# Out:
#   Make       Model  Year     HP  ...  MPG-H MPG-C Popularity  Price
# 0  BMW  1 Series M  2011  335.0  ...     26    19       3916  46135
# 1  BMW    1 Series  2011  300.0  ...     28    19       3916  40650
# 2  BMW    1 Series  2011  300.0  ...     28    20       3916  36350
# 3  BMW    1 Series  2011  230.0  ...     28    18       3916  29450
# 4  BMW    1 Series  2011  230.0  ...     28    18       3916  34500
#
# [5 rows x 14 columns]

# %%
car_data.shape
# Out:
# (11123, 14)

# %% [markdown]
# * **isnull** function is used here to detect the missing values in the given series object, it returns a boolean same-sized object indicating if the values are NA. **Missing** values gets mapped to **True** and **non-missing** value gets mapped to **False.**

# %%
car_data.isnull()
# Out:
#         Make  Model   Year     HP  ...  MPG-H  MPG-C  Popularity  Price
# 0      False  False  False  False  ...  False  False       False  False
# 1      False  False  False  False  ...  False  False       False  False
# 2      False  False  False  False  ...  False  False       False  False
# 3      False  False  False  False  ...  False  False       False  False
# 4      False  False  False  False  ...  False  False       False  False
# ...      ...    ...    ...    ...  ...    ...    ...         ...    ...
# 11909  False  False  False  False  ...  False  False       False  False
# 11910  False  False  False  False  ...  False  False       False  False
# 11911  False  False  False  False  ...  False  False       False  False
# 11912  False  False  False  False  ...  False  False       False  False
# 11913  False  False  False  False  ...  False  False       False  False
#
# [11123 rows x 14 columns]

# %% [markdown]
# * **isnull().sum()** returns the number of missing values in the data set.

# %%
car_data.isnull().sum()
# Out:
# Make                0
# Model               0
# Year                0
# HP                 69
# Cylinders          30
# Transmission        0
# Drive Mode          0
# Number of Doors     6
# Vehicle Size        0
# Vehicle Style       0
# MPG-H               0
# MPG-C               0
# Popularity          0
# Price               0
# dtype: int64

# %% [markdown]
# From the above output we concude that there are null values in the data set in **HP, Cylinders & Number of Doors** columns.

# %% [markdown]
# **4.1-> Filling the mising data.**

# %% [markdown]
# To fill the missing data we use **fillna** function to fill **NA/NaN** using specified method. Here we are using **median** to fill the data because the missing data in each columns are of **integer type.**

# %%
car_data['HP'].fillna(car_data['HP'].median(), inplace = True)

# %%
car_data['Cylinders'].fillna(car_data['Cylinders'].median(), inplace = True)

# %%
car_data['Number of Doors'].fillna(car_data['Number of Doors'].median(), inplace = True)

# %%
car_data.isnull().sum()
# Out:
# Make               0
# Model              0
# Year               0
# HP                 0
# Cylinders          0
# Transmission       0
# Drive Mode         0
# Number of Doors    0
# Vehicle Size       0
# Vehicle Style      0
# MPG-H              0
# MPG-C              0
# Popularity         0
# Price              0
# dtype: int64

# %% [markdown]
# > **5-> Checking for Outliers & Plotting Graph**
#
# ---

# %% [markdown]
# The difference between a good and an average machine learning model is often its **ability to clean data**. One of the biggest challenges in data cleaning is the **identification and treatment of outliers.**

# %% [markdown]
# **In statistics, an outlier is an observation point that is distant from other observations.** And this point can effect the final results, graphs and the plots and so checking for outliers and removing them becomes a vital step.

# %% [markdown]
# There can be many reasons for the presence of **outliers** in the data. Sometimes the **outliers** may be genuine, while in other cases, they could exist because of **data entry errors**.

# %%
car_data.boxplot(figsize = (10,10))

# %% [markdown]
# We can observe from the above plot that there are points that are distant from other observations and this will effect our plots and results.

# %%
car_data.hist(figsize = (10 , 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f83c6f2d588>,
# ...
#       dtype=object)

# %% [markdown]
# Plotting **boxplot** for each columns gives us a clear view of points that are in distant from other observations. And by looking at the plot we can make better formulas or algorithms to **remove outliers** so that we don't remove any important observations or points which will effect negatively in data visualization and predictions.

# %%
sns.boxplot(x = car_data['Price'])

# %% [markdown]
# * A **box plot** is a method for graphically depicting groups of numerical data through their **quartiles**. Box plots may also have lines extending vertically from the boxes (whiskers) indicating variability outside the upper and lower quartiles.

# %%
sns.boxplot(x = car_data['Cylinders'])

# %%
sns.boxplot(x = car_data['HP'])

# %% [markdown]
# > **Identifying Outliers with Interquartile Range (IQR)**

# %% [markdown]
# The **interquartile range (IQR)** is a measure of statistical dispersion and is calculated as the difference between the **75th and 25th percentiles**. It is represented by the formula **IQR = Q3 − Q1.**

# %%
Q1 = car_data.quantile(0.25)
Q3 = car_data.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Year                   9.0
# HP                   130.0
# Cylinders              2.0
# Number of Doors        2.0
# MPG-H                  8.0
# MPG-C                  6.0
# Popularity          1460.0
# Price              21405.0
# dtype: float64

# %% [markdown]
# The above output prints the IQR scores, which can be used to **detect outliers.**

# %%
car_data1 = car_data[-((car_data < (Q1 - 1.5*IQR)) | (car_data > (Q3 + 1.5*IQR))).any(axis = 1)]
car_data1.shape
# Out:
# (8577, 14)

# %% [markdown]
# If we compare the shape of **car_data & car_data1** , we can obsereve the difference in number of rows, which means we have removed the outliers or the data/points which were in distant from other observations.

# %% [markdown]
# **Another Method**
#
# min_threshold = car_data.Price.quantile(0.25)
#
# max_threshold = car_data.Price.quantile(0.75)
#
# car_data_new = car_data[(car_data.Price<max_threshold)&(car_data.Price>min_threshold)]
#
# car_data_new.shape
#
# **The result using this method was not satisfactory.**

# %% [markdown]
# We draw different graphs and plot the data because it illustrate **relationships in the data**, and also it gives us an idea that our data is in which **range**. We have drawn two graphs of **Price** column. the First graph is based on the data which **contains outliers and duplicate rows** & the second graph has been plotted on data after **removing outliers and duplicate data.**

# %%
sns.kdeplot(data= car_data['Price'], label = "Price" ,shade = True)

# %%
sns.kdeplot(data= car_data1['Price'], label = "Price" ,shade = True)

# %% [markdown]
# * We can clearly observe the differences.

# %%
car_data['Price'].hist(bins = 8)

# %% [markdown]
# Similarly, the bar graph gives us the range of Price, which can be observed from the graph below.

# %%
car_data1['Price'].hist(bins=8)

# %% [markdown]
# > **6-> Car Brands that are most represented in the dataset and the average price among the top Car Brands.**
#
# ---

# %% [markdown]
# This bar graph represents the data which we had in a form of series in **statistical summary**. From this we can clearly observe **Chevrolet** has occcured the most time also we can observe the top 10 Car brands from the graph.

# %%
car_data1['Make'].value_counts().plot(kind = 'bar' ,figsize = [15,5])

# %% [markdown]
# We can see **Chevrolet, Toyota, Volkswagen, Nissan, GMC, Dodge, Mazda, Honda, Suzuki, Infinti** as top 10 brands,

# %%
car_data1['Model'].value_counts().plot(kind = 'bar' ,figsize = [25,5])

# %% [markdown]
# The bar graph below gives an idea of Vehicle Style which have been prefered most. And we can observe that Sedan has been prefered the most.

# %%
car_data1['Vehicle Style'].value_counts().plot.bar()
plt.title("Cars sold based on Body")
plt.ylabel('Number of Cars')
plt.xlabel('Vehical Body Type')
# Out:
# Text(0.5, 0, 'Vehical Body Type')

# %% [markdown]
# > **Finding max Price and the company name**

# %% [markdown]
# Using the max function we find the maximum or the highest price in our data and the company that has the highest priced car.
# We can infer that **Bugatti** has the highest priced car.

# %%
cd = max(car_data['Price'])
car_data['Make'][car_data['Price'] == cd]
# Out:
# 11362    Bugatti
# Name: Make, dtype: object

# %% [markdown]
# **Finding the max Price each company has for its models**

# %% [markdown]
# Now we find the highest priced car in each company and we observe that in our data set we have **47 Car Companies** each with its highest priced car shown below.

# %%
price_data = car_data.groupby('Make')['Price'].max().reset_index()
price_data
# Out:
#              Make    Price
# 0           Acura   156000
# 1      Alfa Romeo    68400
# 2    Aston Martin   320695
# 3            Audi   199900
# 4             BMW   141200
# 5         Bentley   363000
# 6         Bugatti  2065902
# 7           Buick    49625
# 8        Cadillac   104215
# 9       Chevrolet    92395
# 10       Chrysler    49470
# 11          Dodge   120395
# 12           FIAT    31800
# 13        Ferrari   643330
# 14           Ford   149995
# 15            GMC    71665
# 16        Genesis    54550
# 17         HUMMER    43130
# 18          Honda    47070
# 19        Hyundai    68750
# 20       Infiniti    88850
# 21            Kia    61900
# 22    Lamborghini  1500000
# 23     Land Rover   199495
# 24          Lexus   375000
# 25        Lincoln    76650
# 26          Lotus    93225
# 27       Maserati   182009
# 28        Maybach  1382750
# 29          Mazda    44015
# 30        McLaren   280225
# 31  Mercedes-Benz   495000
# 32     Mitsubishi    38995
# ...

# %% [markdown]
# > **Average price among the top car brands.**

# %%
car_data1['price_group'] = pd.cut(car_data1['Price'],[0,20000,40000,60000,80000,100000,600000], labels=['<20k','20-39k','40-59k','60-79k','80-99k','>100k'], include_lowest= True)
car_data1['price_group'] = car_data1['price_group'].astype(object)

# %%
(car_data1['price_group'].value_counts()/len(car_data1)*100).plot.bar(figsize=(10,6))
plt.title("Price group bar diagram")
plt.ylabel('% of Vehicles')
plt.xlabel('Price Group')
# Out:
# Text(0.5, 0, 'Price Group')

# %% [markdown]
# From the above bar graph we observe that most car have price range in between **20-30k**.

# %% [markdown]
# **Pie charts** are generally used to show percentage or proportional data and usually the percentage represented by each category is provided next to the corresponding slice of pie.

# %%
price_data1 = price_data.set_index('Make')

# %%
price_data1.plot(kind = 'pie' , y = 'Price', figsize = [25,25])

# %% [markdown]
# We can observe the pie chart and see the companies with its highest or expensive car. And here also we can see **Bugati** having the expensive or highest priced car.

# %% [markdown]
# > **7-> Plotting the Correlation Matrix**
#
# ---

# %% [markdown]
# A **correlation matrix** is a table showing **correlation coefficients** between variables. Each cell in the table shows the correlation between two variables.

# %% [markdown]
# A **correlation matrix** is used to **summarize data**, as an input into a more advanced analysis, and as a diagnostic for advanced analyses.

# %% [markdown]
# * **corr()** function is used to find the pairwise correlation of all columns in the dataframe. Any na values are automatically excluded.

# %%
car_data1.corr()
# Out:
#                      Year        HP  Cylinders  ...     MPG-C  Popularity     Price
# Year             1.000000  0.324661  -0.106613  ...  0.335114    0.200714  0.592198
# HP               0.324661  1.000000   0.733604  ... -0.553967    0.095288  0.744757
# Cylinders       -0.106613  0.733604   1.000000  ... -0.746535    0.012437  0.388381
# Number of Doors  0.241442  0.040792   0.020905  ...  0.024603   -0.076936  0.131498
# MPG-H            0.373182 -0.452891  -0.691575  ...  0.937008    0.094122 -0.120675
# MPG-C            0.335114 -0.553967  -0.746535  ...  1.000000    0.082506 -0.196708
# Popularity       0.200714  0.095288   0.012437  ...  0.082506    1.000000  0.112736
# Price            0.592198  0.744757   0.388381  ... -0.196708    0.112736  1.000000
#
# [8 rows x 8 columns]

# %% [markdown]
# The correlation of a variable with itself is 1 and if we plot the above output in **heatmap** we can observe the ouput better.

# %% [markdown]
# > **8-> Performing EDA & plotting different graphs.**
#
# ---

# %% [markdown]
# A **heatmap** is a **two-dimensional graphical representation** of data where the individual values that are contained in a **matrix** are represented as colors.

# %% [markdown]
# The **seaborn** python package allows the creation of **annotated heatmaps** which can be tweaked using **Matplotlib** tools as per the creator's requirement.

# %%
plt.figure(figsize=(20,9))
a = sns.heatmap(car_data1.corr(), annot=True, fmt='.2f')

# %% [markdown]
# * Lighter the colour higher will be the positive correlation & the darker the colour higher will be the negative correlation.

# %% [markdown]
# From the heat map we observe that :-
#
# **-> Positive Correlation between :-**
#
#   * Cylinders & HP
#   * MPG-H & MPG-C
#   * Year & Price
#   * Price & HP
#
# **-> Negative Correlation between :-**
#
#   * Cylinders & Highway
#   * MPG-C & Cylinders
#   * MPG-H & HP
#   * Price & MPG-C

# %%
car_data1['Number of Doors'].value_counts(normalize=True).plot(figsize=(6, 6),kind='bar',color='green')
plt.title("Number of Door frequency diagram")
plt.ylabel('Number of Doors')
plt.xlabel('num-of-doors');

# %% [markdown]
# From the above bar graph we can conclude that **70%** of the cars have 4 number of doors.

# %%
car_data1['Cylinders'].value_counts(normalize= True).plot(figsize=(10,8),kind='bar',color='purple')
plt.title("Number of Cylinders")
plt.ylabel('Number of vehicles')
plt.xlabel('Cylinders');

# %% [markdown]
# From the above bar graph we can conclude that **45%** of the cars have 4 cylinders & about **40%** have 6 cylindes.

# %%
car_data1.hist(figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f83bfde6d30>,
# ...
#       dtype=object)

# %% [markdown]
# **Observations from the above Bar Graphs :-**
#
#
# 1. Most of the cars have Cylinders in range 4-6
# 2. Most of the cars have HP in range 110-330
# 3. Most of the cars have Popularity in range 0-2200
# 4. Most of the cars have MPG-C in range 15-20
# 5. Most of the cars have MPG-H in range 22-30
# 6. Most of the cars have Price in range 20-30k
# 7. Most of the cars have 4 number of doors

# %% [markdown]
# **Scatter plots** are used to plot data points on horizontal and vertical axis in the attempt to show how much one variable is affected by another.

# %%
fig, z = plt.subplots(figsize = (10,6))
z.scatter(car_data1['HP'], car_data1['Cylinders'])
z.set_xlabel('HP')
z.set_ylabel('Cylinders')
plt.show()

# %% [markdown]
# Here **scatter plot** has been plotted between **HP and price** from the plot we can easily observe the relation between the two.

# %%
fig, z = plt.subplots(figsize = (10,6))
z.scatter(car_data1['HP'], car_data1['Price'])
z.set_xlabel('HP')
z.set_ylabel('Price')
plt.show()

# %%
plt.rcParams['figure.figsize']=(30, 10)
ax = sns.boxplot(x="Make", y="Price", data=car_data1)

# %%
plt.rcParams['figure.figsize']=(23, 10)
ax = sns.boxplot(x = "Vehicle Style", y = "Price", data = car_data1)

# %%
sns.catplot(data=car_data1, x="Vehicle Style", y="Popularity", hue = 'Drive Mode', kind="point", aspect=5)

# %% [markdown]
# From catplot we can infer that for **vehicle style sedan** is more prefered and for **drive mode rear wheel drive** is most prefered.

# %%
sns.catplot(data=car_data1, y="HP", x="Price" , hue="Vehicle Style" ,kind="point", aspect = 4, height = 8)

# %%
plt.rcParams['figure.figsize']=(10,5)
ax = sns.boxplot(x="Drive Mode", y="Price", data=car_data1)

# %% [markdown]
# From the boxplot we observe that the all wheel drive cars are expensive than any other drive mode cars.

# %%
sns.pairplot(car_data1)

# %% [markdown]
# Observations :-
#
# * Vehicle Mileage decreases as increase in HP
# * As Hp increases Price Increases
# * MPG-C is negatively corelated with price as increase in HP reduces the mileage.

# %% [markdown]
# > **9-> ML MODEL**
#
# ---

# %% [markdown]
# > **Multi-linear Regression**

# %% [markdown]
# **Multiple linear regression (MLR)**, also known simply as **multiple regression**, is a statistical technique that uses several explanatory variables to predict the outcome of a response variable.

# %%
X = car_data1[['Popularity', 'Year', 'HP', 'Cylinders', 'MPG-H', 'MPG-C']].values
Y = car_data1['Price'].values

# %% [markdown]
# **Feature scaling** is an important preprocessing step for **machine learning** algorithms. Standardization involves rescaling the features such that they have the properties of a standard normal distribution with a mean of zero and a standard deviation of one.

# %%
# Featur Scaling
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_Y = StandardScaler()
X = sc_X.fit_transform(X)
Y = sc_Y.fit_transform(Y.reshape(-1,1))

# %%
#splitting the dataset into the training set and test set
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %% [markdown]
# We have splitted the data in the ratio of 20:80, tet size is 20

# %%
#Fitting Multiple Linear Regression to the Training Set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#Predicting the Test Set results
Y_pred = regressor.predict(X_test)
plt.scatter(Y_test, Y_pred)

# %%
sns.distplot((Y_test-Y_pred), bins =50)

# %% [markdown]
# * Through the plot we are checking the **residuals**.

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(Y_test, Y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Y_test, Y_pred)))
print('R2 Score:', metrics.r2_score(Y_test, Y_pred))
# Out:
# Mean Absolute Error: 0.428935861748091
# Root Mean Squared Error: 0.5697839442079168
# R2 Score: 0.6695925295175177

# %% [markdown]
# * By observing the reults from **metrics** we get to know the **Mean Absolute Error, Root Mean Squared Error, R2 Score** when we apply **multi linear regression.**

# %% [markdown]
# > **10-> Applying different algorithms and checking the output**
#
# ---

# %% [markdown]
# > **Polynomial Regression**

# %% [markdown]
# **Polynomial Regression** is a form of linear regression in which the relationship between the independent variable x and dependent variable y is modeled as an nth degree polynomial.

# %%
# Fitting Polynomial Regression to the dataset
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X)
poly_reg.fit(X_poly, Y)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Visualising the Polynomial Regression results
Y_pred = lin_reg_2.predict(poly_reg.fit_transform(X_test))
plt.scatter(Y_test, Y_pred)

# %%
sns.distplot((Y_test-Y_pred), bins =50)

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(Y_test, Y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Y_test, Y_pred)))
print('R2 Score:', metrics.r2_score(Y_test, Y_pred))
# Out:
# Mean Absolute Error: 0.30688808779015675
# Root Mean Squared Error: 0.42275499237798825
# R2 Score: 0.8181107912902588

# %% [markdown]
# By observing the output and comparing them to the output in **multilinear regression** we can conclude that **polynomial regression performed better than MLR**.

# %% [markdown]
# There is a decrease in Mean Absolute Error and Root Mean Squared Error & a increase in **R2** score.

# %% [markdown]
# > **Support Vector Machine (SVR)**

# %% [markdown]
# **Support Vector Machine** can also be used as a regression method, maintaining all the main features that characterize the algorithm (maximal margin). The Support Vector Regression (SVR) uses the same principles as the SVM for classification, with only a few minor differences.

# %%
# Fitting SVR to the dataset
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X_train, Y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
# Predicting a new result
Y_pred = regressor.predict(X_test)
plt.scatter(Y_test, Y_pred)

# %%
sns.distplot((Y_test-Y_pred), bins =50)

# %% [markdown]
# We can observe the changes in graph of **SVM** from the graph of **MLR and Polynomial Regression.** We can infer that the errors have become more normalized.

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(Y_test, Y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Y_test, Y_pred)))
print('R2 Score:', metrics.r2_score(Y_test, Y_pred))
# Out:
# Mean Absolute Error: 0.30058067067132577
# Root Mean Squared Error: 0.43318406022066136
# R2 Score: 0.8090259409353363

# %% [markdown]
# Also a change can be observed in the **metrics** values, by which we can conclude **SVM** performed better than **MLR and Polynomial Regression.**

# %% [markdown]
# > **Decission Tree**

# %% [markdown]
# **Decision tree** builds regression or classification models in the form of a tree structure. It breaks down a dataset into smaller and smaller subsets while at the same time an associated decision tree is incrementally developed. The final result is a tree with decision nodes and leaf nodes.

# %%
# Fitting Decision Tree Regression to the dataset
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state = 0)
regressor.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=0, splitter='best')

# %%
# Predicting a new result
Y_pred = regressor.predict(X_test)
plt.scatter(Y_test, Y_pred)

# %%
sns.distplot((Y_test-Y_pred), bins =50)

# %% [markdown]
# We can observe the changes in graph of **Decision tree** from the graph of **MLR, Polynomial Regression & SVM.** We can infer that the errors have become more normalized.

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(Y_test, Y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Y_test, Y_pred)))
print('R2 Score:', metrics.r2_score(Y_test, Y_pred))
# Out:
# Mean Absolute Error: 0.19973214884128285
# Root Mean Squared Error: 0.3082381924351423
# R2 Score: 0.9033053730625865

# %% [markdown]
# Here also a large change can be observed in the **metrics** values, by which we can conclude **Decission Tree** performed better than **MLR, SVM and Polynomial Regression.**

# %% [markdown]
# > **Random Forest Regression**

# %%
# Fitting Random Forest Regression to the dataset
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 300, random_state = 0)
regressor.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=300, n_jobs=None, oob_score=False,
#                       random_state=0, verbose=0, warm_start=False)

# %%
# Predicting a new result
Y_pred = regressor.predict(X_test)
plt.scatter(Y_test, Y_pred)

# %%
sns.distplot((Y_test-Y_pred), bins =50)

# %% [markdown]
# We can observe the changes in graph of **Random Forest Regression** from the graph of **MLR, Polynomial Regression, Decission Tree & SVM.** We can infer that the errors have become more normalized.

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(Y_test, Y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Y_test, Y_pred)))
print('R2 Score:', metrics.r2_score(Y_test, Y_pred))
# Out:
# Mean Absolute Error: 0.18441160956499258
# Root Mean Squared Error: 0.263178228577163
# R2 Score: 0.9295096994093152

# %% [markdown]
# By observing the values of **matrics** and then comparing it to the other algorithms we can clearly conclude that the **Random Forest Regression** has normalized the errors better than other algorithms and **Random Forest Regression** is the best algorithm here.
