# %% [markdown]
# <a href="https://colab.research.google.com/github/risshabhraj/Car_Project/blob/master/Car_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **EDA on car dataset**

# %% [markdown]
# Importing Libraries

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# importing warnings to ignore or filter any warning occuring in the program.
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Loading the Data

# %%
car_data = pd.read_csv("data.csv")
car_data
# Out:
#           Make       Model  Year  ... city mpg  Popularity   MSRP
# 0          BMW  1 Series M  2011  ...       19        3916  46135
# 1          BMW    1 Series  2011  ...       19        3916  40650
# 2          BMW    1 Series  2011  ...       20        3916  36350
# 3          BMW    1 Series  2011  ...       18        3916  29450
# 4          BMW    1 Series  2011  ...       18        3916  34500
# ...        ...         ...   ...  ...      ...         ...    ...
# 11909    Acura         ZDX  2012  ...       16         204  46120
# 11910    Acura         ZDX  2012  ...       16         204  56670
# 11911    Acura         ZDX  2012  ...       16         204  50620
# 11912    Acura         ZDX  2013  ...       16         204  50920
# 11913  Lincoln      Zephyr  2006  ...       17          61  28995
#
# [11914 rows x 16 columns]

# %%
car_data.head()
# Out:
#   Make       Model  Year  ... city mpg  Popularity   MSRP
# 0  BMW  1 Series M  2011  ...       19        3916  46135
# 1  BMW    1 Series  2011  ...       19        3916  40650
# 2  BMW    1 Series  2011  ...       20        3916  36350
# 3  BMW    1 Series  2011  ...       18        3916  29450
# 4  BMW    1 Series  2011  ...       18        3916  34500
#
# [5 rows x 16 columns]

# %%
car_data.tail()
# Out:
#           Make   Model  Year  ... city mpg  Popularity   MSRP
# 11909    Acura     ZDX  2012  ...       16         204  46120
# 11910    Acura     ZDX  2012  ...       16         204  56670
# 11911    Acura     ZDX  2012  ...       16         204  50620
# 11912    Acura     ZDX  2013  ...       16         204  50920
# 11913  Lincoln  Zephyr  2006  ...       17          61  28995
#
# [5 rows x 16 columns]

# %%
car_data['Make']
# Out:
# 0            BMW
# 1            BMW
# 2            BMW
# 3            BMW
# 4            BMW
#           ...
# 11909      Acura
# 11910      Acura
# 11911      Acura
# 11912      Acura
# 11913    Lincoln
# Name: Make, Length: 11914, dtype: object

# %%
car_data['Make'].value_counts()
# Out:
# Chevrolet        1123
# Ford              881
# Volkswagen        809
# Toyota            746
# Dodge             626
# Nissan            558
# GMC               515
# Honda             449
# Mazda             423
# Cadillac          397
# Mercedes-Benz     353
# Suzuki            351
# BMW               334
# Infiniti          330
# Audi              328
# Hyundai           303
# Volvo             281
# Subaru            256
# Acura             252
# Kia               231
# Mitsubishi        213
# Lexus             202
# Buick             196
# Chrysler          187
# Pontiac           186
# Lincoln           164
# Oldsmobile        150
# Land Rover        143
# Porsche           136
# Saab              111
# Aston Martin       93
# Plymouth           82
# Bentley            74
# Ferrari            69
# FIAT               62
# Scion              60
# Maserati           58
# Lamborghini        52
# Rolls-Royce        31
# Lotus              29
# Tesla              18
# ...

# %%
car_data['Model'].value_counts()
# Out:
# Silverado 1500        156
# Tundra                140
# F-150                 126
# Sierra 1500            90
# Beetle Convertible     89
#                      ...
# Blackwood               1
# Cayman S                1
# G3                      1
# ML55 AMG                1
# Continental GT3-R       1
# Name: Model, Length: 915, dtype: int64
