# %% [markdown]
# <a href="https://colab.research.google.com/github/risshabhraj/Car_Project/blob/master/Car_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **EDA on car dataset**

# %% [markdown]
# **1->  Importing the dataset and the necessary libraries**

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# importing warnings to ignore or filter any warning occuring in the program.
import warnings
warnings.filterwarnings("ignore")
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# **1.1-> Data Loading**

# %%
car_data = pd.read_csv("data.csv")
car_data
# Out:
#           Make       Model  Year  ... city mpg  Popularity   MSRP
# 0          BMW  1 Series M  2011  ...       19        3916  46135
# 1          BMW    1 Series  2011  ...       19        3916  40650
# 2          BMW    1 Series  2011  ...       20        3916  36350
# 3          BMW    1 Series  2011  ...       18        3916  29450
# 4          BMW    1 Series  2011  ...       18        3916  34500
# ...        ...         ...   ...  ...      ...         ...    ...
# 11909    Acura         ZDX  2012  ...       16         204  46120
# 11910    Acura         ZDX  2012  ...       16         204  56670
# 11911    Acura         ZDX  2012  ...       16         204  50620
# 11912    Acura         ZDX  2013  ...       16         204  50920
# 11913  Lincoln      Zephyr  2006  ...       17          61  28995
#
# [11914 rows x 16 columns]

# %% [markdown]
# **1.2-> Statistical Summary & Checking Datatype**

# %%
car_data.head()
# Out:
#   Make       Model  Year  ... city mpg  Popularity   MSRP
# 0  BMW  1 Series M  2011  ...       19        3916  46135
# 1  BMW    1 Series  2011  ...       19        3916  40650
# 2  BMW    1 Series  2011  ...       20        3916  36350
# 3  BMW    1 Series  2011  ...       18        3916  29450
# 4  BMW    1 Series  2011  ...       18        3916  34500
#
# [5 rows x 16 columns]

# %%
car_data.tail()
# Out:
#           Make   Model  Year  ... city mpg  Popularity   MSRP
# 11909    Acura     ZDX  2012  ...       16         204  46120
# 11910    Acura     ZDX  2012  ...       16         204  56670
# 11911    Acura     ZDX  2012  ...       16         204  50620
# 11912    Acura     ZDX  2013  ...       16         204  50920
# 11913  Lincoln  Zephyr  2006  ...       17          61  28995
#
# [5 rows x 16 columns]

# %%
car_data.shape
# Out:
# (11914, 16)

# %%
car_data.describe()
# Out:
#                Year    Engine HP  ...    Popularity          MSRP
# count  11914.000000  11845.00000  ...  11914.000000  1.191400e+04
# mean    2010.384338    249.38607  ...   1554.911197  4.059474e+04
# std        7.579740    109.19187  ...   1441.855347  6.010910e+04
# min     1990.000000     55.00000  ...      2.000000  2.000000e+03
# 25%     2007.000000    170.00000  ...    549.000000  2.100000e+04
# 50%     2015.000000    227.00000  ...   1385.000000  2.999500e+04
# 75%     2016.000000    300.00000  ...   2009.000000  4.223125e+04
# max     2017.000000   1001.00000  ...   5657.000000  2.065902e+06
#
# [8 rows x 8 columns]

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# dtypes: float64(3), int64(5), object(8)
# memory usage: 1.5+ MB

# %%
car_data['Make']
# Out:
# 0            BMW
# 1            BMW
# 2            BMW
# 3            BMW
# 4            BMW
#           ...
# 11909      Acura
# 11910      Acura
# 11911      Acura
# 11912      Acura
# 11913    Lincoln
# Name: Make, Length: 11914, dtype: object

# %%
car_data['Make'].value_counts()
# Out:
# Chevrolet        1123
# Ford              881
# Volkswagen        809
# Toyota            746
# Dodge             626
# Nissan            558
# GMC               515
# Honda             449
# Mazda             423
# Cadillac          397
# Mercedes-Benz     353
# Suzuki            351
# BMW               334
# Infiniti          330
# Audi              328
# Hyundai           303
# Volvo             281
# Subaru            256
# Acura             252
# Kia               231
# Mitsubishi        213
# Lexus             202
# Buick             196
# Chrysler          187
# Pontiac           186
# Lincoln           164
# Oldsmobile        150
# Land Rover        143
# Porsche           136
# Saab              111
# Aston Martin       93
# Plymouth           82
# Bentley            74
# Ferrari            69
# FIAT               62
# Scion              60
# Maserati           58
# Lamborghini        52
# Rolls-Royce        31
# Lotus              29
# Tesla              18
# HUMMER             17
# Maybach            16
# Alfa Romeo          5
# McLaren             5
# Bugatti             3
# Spyker              3
# Genesis             3
# Name: Make, dtype: int64

# %%
car_data['Model'].value_counts()
# Out:
# Silverado 1500           156
# Tundra                   140
# F-150                    126
# Sierra 1500               90
# Beetle Convertible        89
#                         ...
# Accord Plug-In Hybrid      1
# Sierra C3                  1
# Horizon                    1
# XC                         1
# Omni                       1
# Name: Model, Length: 915, dtype: int64

# %%
car_data['MSRP'].describe()
# Out:
# count    1.191400e+04
# mean     4.059474e+04
# std      6.010910e+04
# min      2.000000e+03
# 25%      2.100000e+04
# 50%      2.999500e+04
# 75%      4.223125e+04
# max      2.065902e+06
# Name: MSRP, dtype: float64

# %% [markdown]
# **2-> Dropping Irrelevant columns**

# %%
car_data = car_data.drop(['Market Category', 'Engine Fuel Type'], axis=1)
car_data.head()
# Out:
#   Make       Model  Year  Engine HP  ...  highway MPG city mpg Popularity   MSRP
# 0  BMW  1 Series M  2011      335.0  ...           26       19       3916  46135
# 1  BMW    1 Series  2011      300.0  ...           28       19       3916  40650
# 2  BMW    1 Series  2011      300.0  ...           28       20       3916  36350
# 3  BMW    1 Series  2011      230.0  ...           28       18       3916  29450
# 4  BMW    1 Series  2011      230.0  ...           28       18       3916  34500
#
# [5 rows x 14 columns]

# %% [markdown]
# **3-> Renaming the Columns**

# %%
car_data = car_data.rename(columns = {"Engine HP": "HP", "Engine Cylinders": "Cylinders", "Transmission Type": "Transmission", "Driven_Wheels": "Drive Mode","highway MPG": "MPG-H", "city mpg": "MPG-C", "MSRP": "Price"})
car_data
# Out:
#           Make       Model  Year     HP  ...  MPG-H MPG-C Popularity  Price
# 0          BMW  1 Series M  2011  335.0  ...     26    19       3916  46135
# 1          BMW    1 Series  2011  300.0  ...     28    19       3916  40650
# 2          BMW    1 Series  2011  300.0  ...     28    20       3916  36350
# 3          BMW    1 Series  2011  230.0  ...     28    18       3916  29450
# 4          BMW    1 Series  2011  230.0  ...     28    18       3916  34500
# ...        ...         ...   ...    ...  ...    ...   ...        ...    ...
# 11909    Acura         ZDX  2012  300.0  ...     23    16        204  46120
# 11910    Acura         ZDX  2012  300.0  ...     23    16        204  56670
# 11911    Acura         ZDX  2012  300.0  ...     23    16        204  50620
# 11912    Acura         ZDX  2013  300.0  ...     23    16        204  50920
# 11913  Lincoln      Zephyr  2006  221.0  ...     26    17         61  28995
#
# [11914 rows x 14 columns]

# %% [markdown]
#  **4-> Checking for any duplicates in the data, checking for null values and missing data.**

# %%
car_data.isnull()
# Out:
#         Make  Model   Year     HP  ...  MPG-H  MPG-C  Popularity  Price
# 0      False  False  False  False  ...  False  False       False  False
# 1      False  False  False  False  ...  False  False       False  False
# 2      False  False  False  False  ...  False  False       False  False
# 3      False  False  False  False  ...  False  False       False  False
# 4      False  False  False  False  ...  False  False       False  False
# ...      ...    ...    ...    ...  ...    ...    ...         ...    ...
# 11909  False  False  False  False  ...  False  False       False  False
# 11910  False  False  False  False  ...  False  False       False  False
# 11911  False  False  False  False  ...  False  False       False  False
# 11912  False  False  False  False  ...  False  False       False  False
# 11913  False  False  False  False  ...  False  False       False  False
#
# [11914 rows x 14 columns]

# %%
car_data.isnull().sum()
# Out:
# Make                0
# Model               0
# Year                0
# HP                 69
# Cylinders          30
# Transmission        0
# Drive Mode          0
# Number of Doors     6
# Vehicle Size        0
# Vehicle Style       0
# MPG-H               0
# MPG-C               0
# Popularity          0
# Price               0
# dtype: int64

# %% [markdown]
# **4.1-> Filling the mising data.**

# %%
car_data['HP'].fillna(car_data['HP'].median(), inplace = True)

# %%
car_data['Cylinders'].fillna(car_data['Cylinders'].median(), inplace = True)

# %%
car_data['Number of Doors'].fillna(car_data['Number of Doors'].median(), inplace = True)

# %%
car_data.isnull().sum()
# Out:
# Make               0
# Model              0
# Year               0
# HP                 0
# Cylinders          0
# Transmission       0
# Drive Mode         0
# Number of Doors    0
# Vehicle Size       0
# Vehicle Style      0
# MPG-H              0
# MPG-C              0
# Popularity         0
# Price              0
# dtype: int64

# %% [markdown]
# **5-> Checking for Outliers & Plotting Graph**

# %%
min_threshold, max_threshold = car_data.Price.quantile([0.15, 0.95])
min_threshold, max_threshold
# Out:
# (14498.5, 107530.25000000015)

# %%
car_data[car_data.Price<=min_threshold]
# Out:
#          Make         Model  Year     HP  ...  MPG-H MPG-C Popularity  Price
# 17       Audi           100  1992  172.0  ...     24    17       3105   2000
# 18       Audi           100  1992  172.0  ...     24    17       3105   2000
# 19       Audi           100  1992  172.0  ...     20    16       3105   2000
# 20       Audi           100  1992  172.0  ...     24    17       3105   2000
# 21       Audi           100  1992  172.0  ...     21    16       3105   2000
# ...       ...           ...   ...    ...  ...    ...   ...        ...    ...
# 11794  Subaru            XT  1991  145.0  ...     23    16        640   2000
# 11832     GMC  Yukon Denali  2000  255.0  ...     15    11        549   3949
# 11881     BMW            Z3  2000  193.0  ...     24    17       3916   4976
# 11882     BMW            Z3  2000  193.0  ...     24    17       3916   4697
# 11883     BMW            Z3  2000  170.0  ...     25    17       3916   4755
#
# [1787 rows x 14 columns]

# %%
car_data[car_data.Price>max_threshold]
# Out:
#               Make   Model  Year     HP  ...  MPG-H MPG-C Popularity   Price
# 294        Ferrari     360  2002  400.0  ...     15    10       2774  160829
# 295        Ferrari     360  2002  400.0  ...     15    10       2774  140615
# 296        Ferrari     360  2002  400.0  ...     15    10       2774  150694
# 297        Ferrari     360  2002  400.0  ...     15    10       2774  170829
# 298        Ferrari     360  2003  400.0  ...     15    10       2774  165986
# ...            ...     ...   ...    ...  ...    ...   ...        ...     ...
# 11449  Rolls-Royce  Wraith  2015  624.0  ...     21    13         86  294025
# 11450  Rolls-Royce  Wraith  2016  624.0  ...     21    13         86  304350
# 11903          BMW      Z8  2001  394.0  ...     19    12       3916  128000
# 11904          BMW      Z8  2002  394.0  ...     19    12       3916  130000
# 11905          BMW      Z8  2003  394.0  ...     19    12       3916  131500
#
# [596 rows x 14 columns]

# %%
car_data1 = car_data[(car_data.Price<max_threshold)&(car_data.Price>min_threshold)]
car_data1
# Out:
#           Make       Model  Year     HP  ...  MPG-H MPG-C Popularity  Price
# 0          BMW  1 Series M  2011  335.0  ...     26    19       3916  46135
# 1          BMW    1 Series  2011  300.0  ...     28    19       3916  40650
# 2          BMW    1 Series  2011  300.0  ...     28    20       3916  36350
# 3          BMW    1 Series  2011  230.0  ...     28    18       3916  29450
# 4          BMW    1 Series  2011  230.0  ...     28    18       3916  34500
# ...        ...         ...   ...    ...  ...    ...   ...        ...    ...
# 11909    Acura         ZDX  2012  300.0  ...     23    16        204  46120
# 11910    Acura         ZDX  2012  300.0  ...     23    16        204  56670
# 11911    Acura         ZDX  2012  300.0  ...     23    16        204  50620
# 11912    Acura         ZDX  2013  300.0  ...     23    16        204  50920
# 11913  Lincoln      Zephyr  2006  221.0  ...     26    17         61  28995
#
# [9531 rows x 14 columns]

# %% [markdown]
# **Plotting Price from the data set by using seaborn**

# %%
sns.pairplot(car_data1)

# %%
sns.kdeplot(data= car_data1['Price'], label = "Price" ,shade = True)

# %%
car_data1['Price'].hist(bins=8)

# %%
car_data1['Make'].value_counts().plot(kind = 'bar' ,figsize = [15,5])

# %%
car_data1['Model'].value_counts().plot(kind = 'bar' ,figsize = [25,5])

# %%
msrp_data1 = msrp_data.set_index('Make')

# %%
msrp_data1.plot(kind = 'pie' , y = 'MSRP', figsize = [25,25])

# %% [markdown]
# **Finding max MSRP and the company name**

# %%
cd = max(car_data['MSRP'])
car_data['Make'][car_data['MSRP'] == cd]

# %% [markdown]
# **Finding the max MSRP each company has for its models**

# %%
msrp_data = car_data.groupby('Make')['MSRP'].max().reset_index()
msrp_data
